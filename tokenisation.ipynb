# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk)
#   Using cached click-8.3.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: joblib in c:\users\sbraj\onedrive\pictures\documents\ai&ml\venv\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sbraj\onedrive\pictures\documents\ai&ml\venv\lib\site-packages (from nltk) (2026.4.4)
# Requirement already satisfied: tqdm in c:\users\sbraj\onedrive\pictures\documents\ai&ml\venv\lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in c:\users\sbraj\onedrive\pictures\documents\ai&ml\venv\lib\site-packages (from click->nltk) (0.4.6)
# Using cached nltk-3.9.4-py3-none-any.whl (1.6 MB)
# Using cached click-8.3.2-py3-none-any.whl (108 kB)
# Installing collected packages: click, nltk
#
#    ---------------------------------------- 0/2 [click]
#    ---------------------------------------- 0/2 [click]
#    ---------------------------------------- 0/2 [click]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    ---------------------------------------- 2/2 [nltk]
#
# Successfully installed click-8.3.2 nltk-3.9.4

# %%
corpus=''' Hello Welcome  to Krish Naiks NLP Tutorials.
Please do watch the entire course! to become expert in NLP .'''

# %%
corpus
# Out:
# ' Hello Welcome  to Krish Naiks NLP Tutorials.\nPlease do watch the entire course! to become expert in NLP .'

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sbraj\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import nltk
nltk.download('punkt', download_dir='C:/nltk_data')
# Out:
# [nltk_data] Downloading package punkt to C:/nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sbraj\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\sbraj\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
### tokenisation
### paragraphs --> sentence
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
for sentence in documents:
    print(sentence)
# Out:
#  Hello Welcome  to Krish Naiks NLP Tutorials.
# Please do watch the entire course!
# to become expert in NLP .

# %%
### paragraph into words
### sentence into words
from nltk.tokenize import word_tokenize

# %%
words=word_tokenize(corpus)

# %%
for w in words:
    print(w)
# Out:
# Hello
# Welcome
# to
# Krish
# Naiks
# NLP
# Tutorials
# .
# Please
# do
# watch
# the
# entire
# course
# !
# to
# become
# expert
# in
# NLP
# .

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', 'to', 'Krish', 'Naiks', 'NLP', 'Tutorials', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokeniser=TreebankWordTokenizer()

# %%
tokeniser.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  'to',
#  'Krish',
#  'Naiks',
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
